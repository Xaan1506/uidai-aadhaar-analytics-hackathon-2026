# %% [markdown]
# # 07 - Killer Insight: Dual Load Analysis
#
# Purpose: Combine enrolment and update datasets to generate high-value insights.

# %%
import pandas as pd
import glob
print(glob.glob('data/sample/*.csv'))
